# %%
import pandas as pd

for i in range(2003,2023):
    k = "g"+str(i)
    df = pd.read_csv(f"{k}.csv")
    g1 = df["GAME_ID"]
    new_df = df[df['GAME_ID'].astype(str).str.startswith('1')].copy()
    new_df.to_csv(f"game1/{k}.csv")
